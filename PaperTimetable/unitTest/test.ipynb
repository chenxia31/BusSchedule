# %%
import pickle
import sys
with open('/home/step/data/xcl/JDBUSgroup/data/virtualTimetable/timetableSeqGroundTruth.pkl','rb') as f:
    data = pickle.load(f)
index = [i for i in data]
timetable = data[index[5]]
test = data[index[5]]['timetableChain']

# %%
import pandas as pd
for key in timetable:
    print('new part',key)
    print(type(timetable[key]))
    if isinstance(timetable[key],pd.core.frame.DataFrame):
        print(timetable[key].shape)
        test = timetable[key]
    print(timetable[key])
# Out:
# new part timetableChain
# <class 'pandas.core.frame.DataFrame'>
# (11, 20)
#          Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9 Unnamed: 11 Unnamed: 13
# 嘉定56路时刻表
# 路牌                南          朱          南          朱           南           朱  \
# 1                -2         -2         -2         -2    06:30:00    07:10:00
# 2                -2         -2         -2         -2    06:38:00    07:22:00
# 3                -2         -2   05:15:00   05:50:00    06:46:00    07:34:00
# 4                -2         -2   05:30:00   06:05:00    06:54:00    07:46:00
# 5                -2         -2         -2         -2    07:02:00    07:58:00
# 6                -2         -2   05:40:00   06:17:00    07:10:00    08:10:00
# 7                -2         -2   05:50:00   06:28:00    07:20:00    08:20:00
# 8                -2         -2   06:00:00   06:39:00    07:30:00    08:30:00
# 9                -2         -2   06:10:00   06:50:00    07:45:00    08:40:00
# ...
