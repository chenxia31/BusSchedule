# %%
import pickle
fw=open('../../../data/timetable/timetableSeqGroundTruth.pkl','rb')
dataset=pickle.load(fw)
for key in dataset:
    for key2 in dataset[key]:
        print(key2)
# Out:
# timetableChain
# headwayPoint
# headwayTime
# runningPoint
# runningTime
# mealInterval
# mealCount
# workmodeInterval
# workmodeCount
# timetableChain
# headwayPoint
# headwayTime
# runningPoint
# runningTime
# mealInterval
# mealCount
# workmodeInterval
# workmodeCount
# timetableChain
# headwayPoint
# headwayTime
# runningPoint
# runningTime
# mealInterval
# mealCount
# workmodeInterval
# workmodeCount
# timetableChain
# headwayPoint
# headwayTime
# runningPoint
# runningTime
# mealInterval
# mealCount
# workmodeInterval
# workmodeCount
# timetableChain
# headwayPoint
# headwayTime
# runningPoint
# runningTime
# mealInterval
# mealCount
# workmodeInterval
# workmodeCount
# timetableChain
# headwayPoint
# headwayTime
# runningPoint
# runningTime
# mealInterval
# mealCount
# workmodeInterval
# workmodeCount
# timetableChain
# headwayPoint
# headwayTime
# runningPoint
# runningTime
# mealInterval
# mealCount
# workmodeInterval
# workmodeCount
# timetableChain
# headwayPoint
# ...
